# %%
import numpy as np
import pickle as pkl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import sys, inspect
import re
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from settings import DATA_PATH

sns.set()

# %%
path = "deep_learning/tables/results-2019-12-28-t21-43.csv"
path = os.path.join(DATA_PATH, path)

# %%
df = pd.read_csv(path)

# %%
columns = list(range(3, 9))
columns.extend([11, 12])
df = df.iloc[:, columns]

# %%
df
# Out:
#    dense_sizes  dropout  epochs  batch_size optimizer_cls  learning_rate  \
# 0    (4096, 4)      0.0      10          32          Adam         0.0001
# 1    (4096, 4)      0.0      10          32          Adam         0.0010
# 2    (4096, 4)      0.2      10          32          Adam         0.0001
# 3    (4096, 4)      0.2      10          32          Adam         0.0010
# 4    (4096, 4)      0.5      10          32          Adam         0.0001
# 5    (4096, 4)      0.5      10          32          Adam         0.0010
# 6     (256, 4)      0.0      10          32          Adam         0.0001
# 7     (256, 4)      0.0      10          32          Adam         0.0010
# 8     (256, 4)      0.2      10          32          Adam         0.0001
# 9     (256, 4)      0.2      10          32          Adam         0.0010
# 10    (256, 4)      0.5      10          32          Adam         0.0001
# 11    (256, 4)      0.5      10          32          Adam         0.0010
#
#      accuracy   f1_score
# 0   90.566039  90.002289
# 1   93.396229  92.996872
# 2   89.622641  88.918321
# 3   94.339621  94.011736
# 4   89.622641  89.014894
# 5   94.339621  94.032449
# 6   86.792451  86.160987
# 7   93.396229  93.101077
# 8   86.792451  85.939402
# 9   88.679248  87.370487
# 10  83.962262  83.029102
# 11  89.622641  88.876500

# %%
def generate_latex_table(df):    
    latex_txt = df.to_latex(bold_rows=True, index=False).split('\n')

    latex_txt[0] = '\\begin{tabular}{p{0.28\\textwidth}p{0.1\\textwidth}*{5}{>{\centering\\arraybackslash}p{0.09\\textwidth}}}'

               
    latex_txt.insert(0, '\\begin{table}[h]')
    latex_txt.insert(1, '\\centering')
    latex_txt.insert(-1, '\\caption{\\textcolor{red}{\\textbf{TODO}} (' + path.replace("_", "-") + ')}')
    latex_txt.insert(-1, '\\end{table}')  
    
    print('\n'.join(latex_txt))

# %%
generate_latex_table(df)
# Out:
# \begin{table}[h]
# \centering
# \begin{tabular}{p{0.28\textwidth}p{0.1\textwidth}*{5}{>{\centering\arraybackslash}p{0.09\textwidth}}}
# \toprule
# dense\_sizes &  dropout &  epochs &  batch\_size & optimizer\_cls &  learning\_rate &   accuracy &   f1\_score \\
# \midrule
#   (4096, 4) &      0.0 &      10 &          32 &          Adam &         0.0001 &  90.566039 &  90.002289 \\
#   (4096, 4) &      0.0 &      10 &          32 &          Adam &         0.0010 &  93.396229 &  92.996872 \\
#   (4096, 4) &      0.2 &      10 &          32 &          Adam &         0.0001 &  89.622641 &  88.918321 \\
#   (4096, 4) &      0.2 &      10 &          32 &          Adam &         0.0010 &  94.339621 &  94.011736 \\
#   (4096, 4) &      0.5 &      10 &          32 &          Adam &         0.0001 &  89.622641 &  89.014894 \\
#   (4096, 4) &      0.5 &      10 &          32 &          Adam &         0.0010 &  94.339621 &  94.032449 \\
#    (256, 4) &      0.0 &      10 &          32 &          Adam &         0.0001 &  86.792451 &  86.160987 \\
#    (256, 4) &      0.0 &      10 &          32 &          Adam &         0.0010 &  93.396229 &  93.101077 \\
#    (256, 4) &      0.2 &      10 &          32 &          Adam &         0.0001 &  86.792451 &  85.939402 \\
#    (256, 4) &      0.2 &      10 &          32 &          Adam &         0.0010 &  88.679248 &  87.370487 \\
#    (256, 4) &      0.5 &      10 &          32 &          Adam &         0.0001 &  83.962262 &  83.029102 \\
#    (256, 4) &      0.5 &      10 &          32 &          Adam &         0.0010 &  89.622641 &  88.876500 \\
# \bottomrule
# \end{tabular}
# \caption{\textcolor{red}{\textbf{TODO}} (/media/lukasz/Dane/Studia/IX-semestr/Analiza-obrazow-i-wideo/memotion-images-analysis/data/deep-learning/tables/results-2019-12-28-t21-43.csv)}
# \end{table}
