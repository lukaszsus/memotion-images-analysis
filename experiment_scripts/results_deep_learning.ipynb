# %%
import numpy as np
import pickle as pkl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import sys, inspect
import re
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from settings import DATA_PATH

sns.set()

# %%
path = "deep_learning/tables/results-2019-12-28-t14-57.csv"
path = os.path.join(DATA_PATH, path)

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#     Unnamed: 0 model_name model_cls dense_sizes  dropout  epochs  batch_size  \
# 0            0     model0  VggModel   (4096, 4)      0.0      10          32
# 1            1     model1  VggModel   (4096, 4)      0.0      10          32
# 2            2     model2  VggModel   (4096, 4)      0.2      10          32
# 3            3     model3  VggModel   (4096, 4)      0.2      10          32
# 4            4     model4  VggModel   (4096, 4)      0.5      10          32
# 5            5     model5  VggModel   (4096, 4)      0.5      10          32
# 6            6     model6  VggModel    (256, 4)      0.0      10          32
# 7            7     model7  VggModel    (256, 4)      0.0      10          32
# 8            8     model8  VggModel    (256, 4)      0.2      10          32
# 9            9     model9  VggModel    (256, 4)      0.2      10          32
# 10          10    model10  VggModel    (256, 4)      0.5      10          32
# 11          11    model11  VggModel    (256, 4)      0.5      10          32
#
#    optimizer_cls  learning_rate  epoch_time       time    accuracy    f1_score
# 0           Adam         0.0001    2.724500  27.245002   91.666669   90.992647
# 1           Adam         0.0010    2.082935  20.829346   97.222221   97.058824
# 2           Adam         0.0001    2.106113  21.061132   91.666669   90.751634
# 3           Adam         0.0010    2.077014  20.770136   97.222221   97.058824
# 4           Adam         0.0001    2.069067  20.690665   94.444442   93.933824
# 5           Adam         0.0010    2.062859  20.628593   97.222221   97.058824
# 6           Adam         0.0001    2.081752  20.817521   83.333331   82.066239
# 7           Adam         0.0010    2.066730  20.667304   97.222221   97.017544
# 8           Adam         0.0001    2.068519  20.685189   83.333331   81.862745
# 9           Adam         0.0010    2.070652  20.706525  100.000000  100.000000
# 10          Adam         0.0001    2.071767  20.717669   88.888890   87.439186
# 11          Adam         0.0010    2.069527  20.695273   91.666669   90.751634
