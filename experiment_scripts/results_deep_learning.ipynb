# %%
import numpy as np
import pickle as pkl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import sys, inspect
import re
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from settings import DATA_PATH

sns.set()

# %%
path = "deep_learning/tables/results-2019-12-28-t21-43.csv"
path = os.path.join(DATA_PATH, path)

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#     Unnamed: 0 model_name model_cls dense_sizes  dropout  epochs  batch_size  \
# 0            0     model0  VggModel   (4096, 4)      0.0      10          32
# 1            1     model1  VggModel   (4096, 4)      0.0      10          32
# 2            2     model2  VggModel   (4096, 4)      0.2      10          32
# 3            3     model3  VggModel   (4096, 4)      0.2      10          32
# 4            4     model4  VggModel   (4096, 4)      0.5      10          32
# 5            5     model5  VggModel   (4096, 4)      0.5      10          32
# 6            6     model6  VggModel    (256, 4)      0.0      10          32
# 7            7     model7  VggModel    (256, 4)      0.0      10          32
# 8            8     model8  VggModel    (256, 4)      0.2      10          32
# 9            9     model9  VggModel    (256, 4)      0.2      10          32
# 10          10    model10  VggModel    (256, 4)      0.5      10          32
# 11          11    model11  VggModel    (256, 4)      0.5      10          32
#
#    optimizer_cls  learning_rate  epoch_time       time   accuracy   f1_score
# 0           Adam         0.0001    2.550928  25.509279  90.566039  90.002289
# 1           Adam         0.0010    1.868547  18.685472  93.396229  92.996872
# 2           Adam         0.0001    1.885029  18.850288  89.622641  88.918321
# 3           Adam         0.0010    1.882699  18.826989  94.339621  94.011736
# 4           Adam         0.0001    1.884416  18.844161  89.622641  89.014894
# 5           Adam         0.0010    1.895579  18.955789  94.339621  94.032449
# 6           Adam         0.0001    1.893686  18.936858  86.792451  86.160987
# 7           Adam         0.0010    1.881856  18.818562  93.396229  93.101077
# 8           Adam         0.0001    1.888990  18.889900  86.792451  85.939402
# 9           Adam         0.0010    1.900376  19.003765  88.679248  87.370487
# 10          Adam         0.0001    1.896579  18.965793  83.962262  83.029102
# 11          Adam         0.0010    1.895234  18.952345  89.622641  88.876500
