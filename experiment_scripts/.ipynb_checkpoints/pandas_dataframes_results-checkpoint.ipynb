# %%
import numpy as np
import pickle as pkl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from SETTINGS import DATA_PATH

sns.set()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b6c2370e1f59> in <module>
#      10 parentdir = os.path.dirname(currentdir)
#      11 sys.path.insert(0,parentdir)
# ---> 12 from SETTINGS import DATA_PATH
#      13
#      14 sns.set()
#
# ModuleNotFoundError: No module named 'SETTINGS'

# %%
DATA_PATH = "/home/marta/Documents/PyCharm/memotion-images-analysis/data/"

# %%
def load_file(filename, dir='results'):
    dataset_path = os.path.join(DATA_PATH, f'{dir}/{filename}')
    with open(dataset_path, "rb") as f:
        df_metrics, df_y, confusion_matrices = pkl.load(f)
    return df_metrics, df_y, confusion_matrices

# %%
filename = 'metrics_full_for-pics_hsv_analyser_sat_value_distribution.pkl'
df_metrics, df_y, confusion_matrices = load_file(filename)

# %%
def bold_max(s):
    values = [False for _ in s.values]
    if s.name != 'Classifier':
        max_val = np.max(s.values)
        values = [True if v == max_val else False for v in s.values]
    return ['font-weight: bold' if v else '' for v in values]

def highlight_max_acc(s):
    max_row = np.array(df_metrics['Accuracy'], dtype=np.float32).argmax()
    return ['background-color: darkseagreen' if i == max_row else '' for i, v in enumerate(s.values)]

def highlight_min_70(s):
    values = [True if v >= 70 else False for v in s.values]
    return ['background-color: orange' if v else '' for v in values]

def highlight_max(s):
    values = [False for _ in s.values]
    if s.name != 'Classifier':
        max_val = np.max(s.values)
        values = [True if v == max_val else False for v in s.values]
    return ['background-color: navajowhite' if v else '' for v in values]

# %%
df_metrics
# Out:
#               Classifier Accuracy Fscore
# 0   Gaussian Naive Bayes    70.74  70.64
# 1   Decision Tree (CART)    58.52  57.86
# 2          Random Forest    74.72  72.78
# 3   k Nearest Neighbours    62.22  56.96
# 4  Multilayer Perceptron    66.19  63.79

# %%
df_metrics.style.apply(bold_max).apply(highlight_max_acc)
# Out:
# <style  type="text/css" >
#     #T_427a0ee4_1a6d_11ea_8436_acb57d091c09row2_col0 {
#             : ;
#             background-color:  darkseagreen;
#         }    #T_427a0ee4_1a6d_11ea_8436_acb57d091c09row2_col1 {
#             font-weight:  bold;
#             background-color:  darkseagreen;
#         }    #T_427a0ee4_1a6d_11ea_8436_acb57d091c09row2_col2 {
#             font-weight:  bold;
#             background-color:  darkseagreen;
#         }</style><table id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Classifier</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Fscore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row0_col0" class="data row0 col0" >Gaussian Naive Bayes</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row0_col1" class="data row0 col1" >70.74</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row0_col2" class="data row0 col2" >70.64</td>
#             </tr>
#             <tr>
#                         <th id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row1_col0" class="data row1 col0" >Decision Tree (CART)</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row1_col1" class="data row1 col1" >58.52</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row1_col2" class="data row1 col2" >57.86</td>
#             </tr>
#             <tr>
#                         <th id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row2_col0" class="data row2 col0" >Random Forest</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row2_col1" class="data row2 col1" >74.72</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row2_col2" class="data row2 col2" >72.78</td>
#             </tr>
#             <tr>
#                         <th id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row3_col0" class="data row3 col0" >k Nearest Neighbours</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row3_col1" class="data row3 col1" >62.22</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row3_col2" class="data row3 col2" >56.96</td>
#             </tr>
#             <tr>
#                         <th id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row4_col0" class="data row4 col0" >Multilayer Perceptron</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row4_col1" class="data row4 col1" >66.19</td>
#                         <td id="T_427a0ee4_1a6d_11ea_8436_acb57d091c09row4_col2" class="data row4 col2" >63.79</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Analiza wszystkich wyników

# %%
filenames = glob.glob(f'{DATA_PATH}/results/metrics/pics/*')
filenames = sorted(filenames)

metrics, metric_names = [], []
for filename in filenames:
    df_metrics, df_y, confusion_matrices = load_file(filename.split('/')[-1], dir='results/metrics/pics')
    metrics.append(df_metrics)
    metric_names.append(filename.split('/')[-1][17:-7])
    
metric_names = [mn.replace('_', ' ') for mn in metric_names]
feature_count = [3, 1, 1, 1, 8, 478, 18, 400, 60, 5, 5, 11, 489, 499]

# %%
acc = []
for m in metrics:
    acc.append(m['Accuracy'].values)
    
print(np.array(acc).shape)
# Out:
# (14, 5)

# %%
tuples = list(zip(metric_names, feature_count))
multiindex = pd.MultiIndex.from_tuples(tuples, names=['feature name', 'no of features'])

# %%
df = pd.DataFrame(np.array(acc).T, columns=multiindex)
df = df.set_index(metrics[0]['Classifier'], append=True)
df
# Out:
# feature name            bilateral filter  \
# no of features                       3
#   Classifier
# 0 Gaussian Naive Bayes              64.2
# 1 Decision Tree (CART)             65.62
# 2 Random Forest                    66.48
# 3 k Nearest Neighbours             57.95
# 4 Multilayer Perceptron            57.39
#
# feature name            bilateral filter h from hsv differences  \
# no of features                                              1
#   Classifier
# 0 Gaussian Naive Bayes                                    43.18
# 1 Decision Tree (CART)                                    48.86
# 2 Random Forest                                           38.07
# 3 k Nearest Neighbours                                    43.18
# 4 Multilayer Perceptron                                   44.89
#
# feature name            bilateral filter mean color diffs  \
# no of features                                        1
#   Classifier
# 0 Gaussian Naive Bayes                              60.51
# 1 Decision Tree (CART)                               62.5
# 2 Random Forest                                     55.68
# 3 k Nearest Neighbours                              55.97
# 4 Multilayer Perceptron                             48.58
#
# feature name            bilateral filter n color diff  \
# no of features                                    1
#   Classifier
# 0 Gaussian Naive Bayes                          45.45
# 1 Decision Tree (CART)                          50.57
# 2 Random Forest                                 36.36
# 3 k Nearest Neighbours                          38.07
# 4 Multilayer Perceptron                         46.59
#
# feature name            color counter edges detector hsv analyser  \
# no of features                                   8            478
#   Classifier
# 0 Gaussian Naive Bayes                         55.68        71.88
# 1 Decision Tree (CART)                         54.83        67.05
# 2 Random Forest                                61.65        75.57
# 3 k Nearest Neighbours                         55.11        63.35
# 4 Multilayer Perceptron                        59.09        70.45
#
# feature name            hsv analyser hsv var  \
# no of features                           18
#   Classifier
# 0 Gaussian Naive Bayes                 59.09
# 1 Decision Tree (CART)                 67.61
# 2 Random Forest                        69.32
# 3 k Nearest Neighbours                 63.92
# 4 Multilayer Perceptron                 57.1
#
# feature name            hsv analyser sat value distribution  \
# no of features                                          400
#   Classifier
# 0 Gaussian Naive Bayes                                71.02
# 1 Decision Tree (CART)                                59.94
# 2 Random Forest                                        73.3
# 3 k Nearest Neighbours                                 62.5
# 4 Multilayer Perceptron                               66.48
#
# feature name            hsv analyser saturation distribution kmeans hsv  \
# no of features                                           60         5
#   Classifier
# 0 Gaussian Naive Bayes                                 65.62      55.11
# 1 Decision Tree (CART)                                 62.78      46.02
# 2 Random Forest                                        66.19      54.83
# 3 k Nearest Neighbours                                 62.78      50.85
# 4 Multilayer Perceptron                                68.75       57.1
#
# feature name            kmeans mean scalar scalar hsv scalar hsv kmeans
# no of features                  5      11         489               499
#   Classifier
# 0 Gaussian Naive Bayes        55.11  65.62      73.86             74.43
# 1 Decision Tree (CART)        55.68  67.05      66.48             66.48
# 2 Random Forest               53.98  74.43      75.28                75
# 3 k Nearest Neighbours        52.84  57.95       62.5             63.07
# 4 Multilayer Perceptron       52.56  60.23      78.12             76.14

# %%
df.style.apply(bold_max).apply(highlight_max).apply(highlight_min_70)
# Out:
# <style  type="text/css" >
#     #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col5 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col7 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col12 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col13 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row1_col1 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row1_col2 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row1_col3 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row1_col10 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col0 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col4 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col5 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col6 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col7 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col11 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col12 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row2_col13 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row4_col5 {
#             : ;
#             : ;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row4_col8 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row4_col9 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             : ;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row4_col12 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             background-color:  orange;
#         }    #T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row4_col13 {
#             font-weight:  bold;
#             background-color:  navajowhite;
#             background-color:  orange;
#         }</style><table id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >feature name</th>        <th class="col_heading level0 col0" >bilateral filter</th>        <th class="col_heading level0 col1" >bilateral filter h from hsv differences</th>        <th class="col_heading level0 col2" >bilateral filter mean color diffs</th>        <th class="col_heading level0 col3" >bilateral filter n color diff</th>        <th class="col_heading level0 col4" >color counter edges detector</th>        <th class="col_heading level0 col5" >hsv analyser</th>        <th class="col_heading level0 col6" >hsv analyser hsv var</th>        <th class="col_heading level0 col7" >hsv analyser sat value distribution</th>        <th class="col_heading level0 col8" >hsv analyser saturation distribution</th>        <th class="col_heading level0 col9" >kmeans hsv</th>        <th class="col_heading level0 col10" >kmeans mean</th>        <th class="col_heading level0 col11" >scalar</th>        <th class="col_heading level0 col12" >scalar hsv</th>        <th class="col_heading level0 col13" >scalar hsv kmeans</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >no of features</th>        <th class="col_heading level1 col0" >3</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >1</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" >8</th>        <th class="col_heading level1 col5" >478</th>        <th class="col_heading level1 col6" >18</th>        <th class="col_heading level1 col7" >400</th>        <th class="col_heading level1 col8" >60</th>        <th class="col_heading level1 col9" >5</th>        <th class="col_heading level1 col10" >5</th>        <th class="col_heading level1 col11" >11</th>        <th class="col_heading level1 col12" >489</th>        <th class="col_heading level1 col13" >499</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Classifier</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09level1_row0" class="row_heading level1 row0" >Gaussian Naive Bayes</th>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col0" class="data row0 col0" >64.2</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col1" class="data row0 col1" >43.18</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col2" class="data row0 col2" >60.51</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col3" class="data row0 col3" >45.45</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col4" class="data row0 col4" >55.68</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col5" class="data row0 col5" >71.88</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col6" class="data row0 col6" >59.09</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col7" class="data row0 col7" >71.02</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col8" class="data row0 col8" >65.62</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col9" class="data row0 col9" >55.11</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col10" class="data row0 col10" >55.11</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col11" class="data row0 col11" >65.62</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col12" class="data row0 col12" >73.86</td>
#                         <td id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09row0_col13" class="data row0 col13" >74.43</td>
#             </tr>
#             <tr>
#                         <th id="T_8d7b6cfa_1a89_11ea_8436_acb57d091c09level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_8d7b6cfa_1a89_11ea_8

# %% [markdown]
# ## Color Counter w 3D

# %%
import cv2 
from PIL import Image

# %%
def load_image_by_cv2(file_path):
    path = os.path.join(DATA_PATH, file_path)
    img = Image.open(path)
    img.load()
    data = np.asarray(img, dtype=np.uint8)
    return data

# %%
img = load_image_by_cv2('results/cartoon.jpg')
img.shape
# Out:
# (433, 577, 3)

# %%
h, w, d = img.shape
n_pix = h * w
im = img.reshape((-1, 3))
im_colors = np.unique(im, axis=0)
im_colors.shape
# Out:
# (26198, 3)

# %%
r = np.unique(im_colors[:, 0])
g = np.unique(im_colors[:, 1])
b = np.unique(im_colors[:, 2])

r.shape[0], g.shape[0], b.shape[0]
# Out:
# (256, 254, 255)

# %%
im_colors[0]
# Out:
# array([ 0,  7, 33], dtype=uint8)

# %%
rg_array, b_values = im_colors[:, 0:2], im_colors[:, 2]
rg_array[0], b_values[0]
# Out:
# (array([0, 7], dtype=uint8), 33)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
url = 'https://python-graph-gallery.com/wp-content/uploads/volcano.csv'
data = pd.read_csv(url)

data
# Out:
#      V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  ...  V52  V53  V54  V55  \
# 0   100  100  101  101  101  101  101  100  100  100  ...  107  107  107  106
# 1   101  101  102  102  102  102  102  101  101  101  ...  108  108  107  107
# 2   102  102  103  103  103  103  103  102  102  102  ...  109  108  108  107
# 3   103  103  104  104  104  104  104  103  103  103  ...  109  109  108  108
# 4   104  104  105  105  105  105  105  104  104  103  ...  110  109  109  108
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 82   99   99   99   99  100  100  101  101  102  102  ...   95   95   95   95
# 83   98   99   99   99   99  100  100  101  101  102  ...   95   95   94   94
# 84   98   98   98   99   99   99  100  100  101  101  ...   94   94   94   94
# 85   97   98   98   98   99   99   99  100  100  100  ...   94   94   94   94
# 86   97   97   97   98   98   99   99   99  100  100  ...   94   94   94   94
#
#     V56  V57  V58  V59  V60  V61
# 0   106  105  105  104  104  103
# 1   106  106  105  105  104  104
# 2   107  106  106  105  105  104
# 3   107  107  106  106  105  105
# 4   107  107  107  106  106  105
# ..  ...  ...  ...  ...  ...  ...
# 82   94   94   94   94   94   94
# 83   94   94   94   94   94   94
# 84   94   94   94   94   94   94
# 85   94   94   94   94   94   94
# 86   94   94   94   94   94   94
#
# [87 rows x 61 columns]

# %%
 
# Get the data (csv file is hosted on the web)
url = 'https://python-graph-gallery.com/wp-content/uploads/volcano.csv'
data = pd.read_csv(url)
 
# Transform it to a long format
df = data.unstack().reset_index()
df.columns = ["X","Y","Z"]
 
# And transform the old column name in something numeric
df['X'] = pd.Categorical(df['X'])
df['X'] = df['X'].cat.codes
 
for angle in range(90, 200, 10):
    print(angle)
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
 
    # Set the angle of the camera
    ax.view_init(30, angle)
 
    # Save it
    filename = 'animations/test'+str(angle)+'.png'
    plt.savefig(filename, dpi=128)
    plt.gca()
    
    plt.show()
# Out:
# 90
# 100
# 110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-eddde3c80dfa> in <module>
#      28     # Save it
#      29     filename = 'animations/test'+str(angle)+'.png'
# ---> 30     plt.savefig(filename, dpi=128)
#      31     plt.gca()
#      32
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     290                 sorted(self.collections,
#     291                        key=lambda col: col.do_3d_projection(renderer),
# --> 292                        reverse=True)):
#     293             col.zorder = zorder_offset + i
#     294         for i, patch in enumerate(
#
# ~/.local/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in <lambda>(col)
#     289         for i, col in enumerate(
#     290                 sorted(self.collections,
# --> 291                        key=lambda col: col.do_3d_projection(renderer),
#     292                        reverse=True)):
#     293             col.zorder = zorder_offset + i
#
# ~/.local/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in do_3d_projection(self, renderer)
#     708              for idx, ((xs, ys, zs), fc, ec)
#     709              in enumerate(zip(xyzlist, cface, cedge))),
# --> 710             key=lambda x: x[0], reverse=True)
#     711
#     712         segments_2d = [s for z, s, fc, ec, idx in z_segments_2d]
#
# ~/.local/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in <genexpr>(.0)
#     706         z_segments_2d = sorted(
#     707             ((self._zsortfunc(zs), np.column_stack([xs, ys]), fc, ec, idx)
# --> 708              for idx, ((xs, ys, zs), fc, ec)
#     709              in enumerate(zip(xyzlist, cface, cedge))),
#     710             key=lambda x: x[0], reverse=True)
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/shape_base.py in column_stack(tup)
#     638         if arr.ndim < 2:
#     639             arr = array(arr, copy=False, subok=True, ndmin=2).T
# --> 640         arrays.append(arr)
#     641     return _nx.concatenate(arrays, 1)
#     642
#
# KeyboardInterrupt:
